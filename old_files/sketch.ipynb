# %% [markdown]
# Language: Python </br>
# Framework: Flask (serwer aplikajci) </br>
# Biblioteka: https (do zapytań) </br>
# ORM: SQlAlchemy </br>
# Harmonogrowanie zadań: Celery </br>

# %% [markdown]
# To run venv: </br>

# %%
import mysql.connector
from flask import Flask
from flask_sqlalchemy import SQLAlchemy

# %%
#Do połączenia trzeba używać albo VPNa albo być w sieci AGH.

# database = mysql.connector.connect(
#     host='mysql.agh.edu.pl',
#     username='michals1',
#     password='ZDg8L4NMGhAVDkGV',
#     database='michals1',
#     port='3306'
# )

# %%
app = Flask(__name__)
app.config['SQLALCHEMY_DATABASE_URI'] = 'mysql+mysqlconnector://michals1:ZDg8L4NMGhAVDkGV@mysql.agh.edu.pl:3306/michals1'
db = SQLAlchemy(app)

# %%
class Location(db.Model):
    id = db.Column(db.Integer, primary_key=True)
    latitude = db.Column(db.Float, nullable=False)
    longitude = db.Column(db.Float, nullable=False)
    country = db.Column(db.String(100), nullable=False)
    city = db.Column(db.String(100), nullable=False)
    street = db.Column(db.String(100), nullable=True)
    number = db.Column(db.String(10), nullable=True)
    elevation = db.Column(db.Float, nullable=True)
    air_quality_data = db.relationship('AirQualityData', backref='location', lazy=True)

class AirQualityData(db.Model):
    id = db.Column(db.Integer, primary_key=True)
    timestamp = db.Column(db.DateTime, nullable=False)
    pm1 = db.Column(db.Float, nullable=False)
    pm25 = db.Column(db.Float, nullable=False)
    pm10 = db.Column(db.Float, nullable=False)
    aqi = db.Column(db.Float, nullable=False)
    pressure = db.Column(db.Float, nullable=False)
    humidity = db.Column(db.Float, nullable=False)
    temperature = db.Column(db.Float, nullable=False)
    location_id = db.Column(db.Integer, db.ForeignKey('location.id'), nullable=False)

# %%
from flask import Flask
from flask_sqlalchemy import SQLAlchemy

# %%
app = Flask(__name__)
app.config['SQLALCHEMY_DATABASE_URI'] = 'mysql+mysqlconnector://michals1:ZDg8L4NMGhAVDkGV@mysql.agh.edu.pl:3306/michals1'
db = SQLAlchemy(app)

# %%
import urllib.request
import json

# %%
headers = {
        "Accept": "application/json",
        "apikey": 'Y7ib9CyZfvqgcPXxEnSUtRkps8TmSIOb'
    }

# %%
url_measurements  = f'https://airapi.airly.eu/v2/measurements/location?locationId={37}'
response_measurements = urllib.request.Request(url_measurements, headers=headers)

# %%
with urllib.request.urlopen(response_measurements) as response:
    data_measurements = json.load(response)

# %%
data_measurements
# Out:
# {'current': {'fromDateTime': '2024-06-20T12:00:00.000Z',
#   'tillDateTime': '2024-06-20T13:00:00.000Z',
#   'values': [{'name': 'PM25', 'value': 7.58},
#    {'name': 'PM10', 'value': 15.22},
#    {'name': 'NO2', 'value': 4.31},
#    {'name': 'O3', 'value': 82.99},
#    {'name': 'SO2', 'value': 5.87},
#    {'name': 'CO', 'value': 294.83}],
#   'indexes': [{'name': 'AIRLY_CAQI',
#     'value': 15.22,
#     'level': 'VERY_LOW',
#     'description': 'Great air here today!',
#     'advice': 'Breathe to fill your lungs!',
#     'color': '#6BC926'}],
#   'standards': [{'name': 'WHO',
#     'pollutant': 'O3',
#     'limit': 100.0,
#     'percent': 82.99,
#     'averaging': '8h'},
#    {'name': 'WHO',
#     'pollutant': 'SO2',
#     'limit': 40.0,
#     'percent': 14.67,
#     'averaging': '24h'},
#    {'name': 'WHO',
#     'pollutant': 'PM25',
#     'limit': 15.0,
#     'percent': 50.53,
#     'averaging': '24h'},
#    {'name': 'WHO',
#     'pollutant': 'CO',
#     'limit': 4000.0,
#     'percent': 7.37,
#     'averaging': '24h'},
#    {'name': 'WHO',
#     'pollutant': 'PM10',
#     'limit': 45.0,
#     'percent': 33.82,
#     'averaging': '24h'},
#    {'name': 'WHO',
#     'pollutant': 'NO2',
#     'limit': 25.0,
#     'percent': 17.23,
#     'averaging': '24h'}]},
#  'history': [{'fromDateTime': '2024-06-19T14:00:00.000Z',
#    'tillDateTime': '2024-06-19T15:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 7.79},
#     {'name': 'PM10', 'value': 17.77},
#     {'name': 'NO2', 'value': 7.65},
#     {'name': 'O3', 'value': 72.17},
#     {'name': 'SO2', 'value': 5.69},
#     {'name': 'CO', 'value': 332.67}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 17.78,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Catch your breath!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 72.17,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.22,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 51.91,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 8.32,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 39.49,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 30.61,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-19T15:00:00.000Z',
#    'tillDateTime': '2024-06-19T16:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 7.57},
#     {'name': 'PM10', 'value': 11.08},
#     {'name': 'NO2', 'value': 8.78},
#     {'name': 'O3', 'value': 68.95},
#     {'name': 'SO2', 'value': 5.72},
#     {'name': 'CO', 'value': 320.95}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 12.63,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Zero dust - zero worries!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 68.95,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.29,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 50.48,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 8.02,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 24.63,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 35.1,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-19T16:00:00.000Z',
#    'tillDateTime': '2024-06-19T17:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 7.88},
#     {'name': 'PM10', 'value': 12.44},
#     {'name': 'NO2', 'value': 9.38},
#     {'name': 'O3', 'value': 65.77},
#     {'name': 'SO2', 'value': 5.87},
#     {'name': 'CO', 'value': 327.1}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 13.13,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Perfect air for exercising! Go for it!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 65.77,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.69,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 52.5,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 8.18,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 27.64,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 37.51,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-19T17:00:00.000Z',
#    'tillDateTime': '2024-06-19T18:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.05},
#     {'name': 'PM10', 'value': 12.61},
#     {'name': 'NO2', 'value': 9.64},
#     {'name': 'O3', 'value': 65.78},
#     {'name': 'SO2', 'value': 5.89},
#     {'name': 'CO', 'value': 325.56}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 13.43,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Catch your breath!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 65.78,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.73,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 53.69,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 8.14,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 28.03,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 38.56,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-19T18:00:00.000Z',
#    'tillDateTime': '2024-06-19T19:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.33},
#     {'name': 'PM10', 'value': 12.45},
#     {'name': 'NO2', 'value': 9.73},
#     {'name': 'O3', 'value': 66.33},
#     {'name': 'SO2', 'value': 5.76},
#     {'name': 'CO', 'value': 320.6}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 13.9,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Breathe deeply!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 66.33,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.4,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 55.57,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 8.02,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 27.66,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 38.91,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-19T19:00:00.000Z',
#    'tillDateTime': '2024-06-19T20:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.02},
#     {'name': 'PM10', 'value': 11.14},
#     {'name': 'NO2', 'value': 8.65},
#     {'name': 'O3', 'value': 69.71},
#     {'name': 'SO2', 'value': 5.48},
#     {'name': 'CO', 'value': 308.9}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 13.37,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'The air is great!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 69.71,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 13.69,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 53.46,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.72,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 24.76,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 34.59,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-19T20:00:00.000Z',
#    'tillDateTime': '2024-06-19T21:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.25},
#     {'name': 'PM10', 'value': 10.49},
#     {'name': 'NO2', 'value': 8.32},
#     {'name': 'O3', 'value': 69.9},
#     {'name': 'SO2', 'value': 5.53},
#     {'name': 'CO', 'value': 309.35}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 13.75,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Green, green, green!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 69.9,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 13.82,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 54.98,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.73,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 23.31,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 33.29,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-19T21:00:00.000Z',
#    'tillDateTime': '2024-06-19T22:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.79},
#     {'name': 'PM10', 'value': 10.12},
#     {'name': 'NO2', 'value': 5.16},
#     {'name': 'O3', 'value': 71.57},
#     {'name': 'SO2', 'value': 5.56},
#     {'name': 'CO', 'value': 302.42}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 14.66,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Green, green, green!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 71.57,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 13.9,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 58.62,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.56,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 22.48,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 20.65,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-19T22:00:00.000Z',
#    'tillDateTime': '2024-06-19T23:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.43},
#     {'name': 'PM10', 'value': 9.7},
#     {'name': 'NO2', 'value': 3.81},
#     {'name': 'O3', 'value': 70.7},
#     {'name': 'SO2', 'value': 5.89},
#     {'name': 'CO', 'value': 298.78}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 14.06,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Green, green, green!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 70.7,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.73,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 56.2,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.47,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 21.55,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 15.22,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-19T23:00:00.000Z',
#    'tillDateTime': '2024-06-20T00:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.31},
#     {'name': 'PM10', 'value': 9.54},
#     {'name': 'NO2', 'value': 3.58},
#     {'name': 'O3', 'value': 69.56},
#     {'name': 'SO2', 'value': 5.9},
#     {'name': 'CO', 'value': 300.57}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 13.86,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Breathe deep! The air is clean!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 69.56,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.74,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 55.42,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.51,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 21.19,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 14.32,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T00:00:00.000Z',
#    'tillDateTime': '2024-06-20T01:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.17},
#     {'name': 'PM10', 'value': 9.39},
#     {'name': 'NO2', 'value': 3.44},
#     {'name': 'O3', 'value': 65.97},
#     {'name': 'SO2', 'value': 5.89},
#     {'name': 'CO', 'value': 300.65}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 13.62,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': "It couldn't be better ;)",
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 65.97,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.73,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 54.44,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.52,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 20.86,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 13.76,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T01:00:00.000Z',
#    'tillDateTime': '2024-06-20T02:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.2},
#     {'name': 'PM10', 'value': 9.58},
#     {'name': 'NO2', 'value': 3.99},
#     {'name': 'O3', 'value': 57.45},
#     {'name': 'SO2', 'value': 5.82},
#     {'name': 'CO', 'value': 296.51}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 13.67,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Dear me, how wonderful!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 57.45,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.54,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 54.66,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.41,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 21.29,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 15.95,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T02:00:00.000Z',
#    'tillDateTime': '2024-06-20T03:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.04},
#     {'name': 'PM10', 'value': 9.49},
#     {'name': 'NO2', 'value': 5.06},
#     {'name': 'O3', 'value': 53.56},
#     {'name': 'SO2', 'value': 5.74},
#     {'name': 'CO', 'value': 299.53}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 13.41,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Breathe as much as you can!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 53.56,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.35,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 53.61,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.49,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 21.09,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 20.26,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T03:00:00.000Z',
#    'tillDateTime': '2024-06-20T04:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.48},
#     {'name': 'PM10', 'value': 10.16},
#     {'name': 'NO2', 'value': 6.6},
#     {'name': 'O3', 'value': 50.92},
#     {'name': 'SO2', 'value': 5.79},
#     {'name': 'CO', 'value': 305.11}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 14.14,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Green, green, green!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 50.92,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.47,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 56.56,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.63,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 22.58,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 26.4,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T04:00:00.000Z',
#    'tillDateTime': '2024-06-20T05:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 7.83},
#     {'name': 'PM10', 'value': 10.01},
#     {'name': 'NO2', 'value': 7.28},
#     {'name': 'O3', 'value': 53.3},
#     {'name': 'SO2', 'value': 5.78},
#     {'name': 'CO', 'value': 307.14}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 13.06,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'The air is grand today. ;)',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 53.3,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.45,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 52.23,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.68,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 22.24,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 29.11,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T05:00:00.000Z',
#    'tillDateTime': '2024-06-20T06:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 9.61},
#     {'name': 'PM10', 'value': 23.86},
#     {'name': 'NO2', 'value': 5.36},
#     {'name': 'O3', 'value': 59.79},
#     {'name': 'SO2', 'value': 5.72},
#     {'name': 'CO', 'value': 301.75}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 23.86,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Breathe deeply!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 59.79,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.29,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 64.07,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.54,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 53.02,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 21.44,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T06:00:00.000Z',
#    'tillDateTime': '2024-06-20T07:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 9.41},
#     {'name': 'PM10', 'value': 21.5},
#     {'name': 'NO2', 'value': 5.74},
#     {'name': 'O3', 'value': 60.44},
#     {'name': 'SO2', 'value': 5.63},
#     {'name': 'CO', 'value': 304.73}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 21.5,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Enjoy life!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 60.44,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.08,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 62.76,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.62,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 47.77,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 22.97,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T07:00:00.000Z',
#    'tillDateTime': '2024-06-20T08:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.62},
#     {'name': 'PM10', 'value': 15.79},
#     {'name': 'NO2', 'value': 4.85},
#     {'name': 'O3', 'value': 65.84},
#     {'name': 'SO2', 'value': 5.74},
#     {'name': 'CO', 'value': 303.13}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 15.8,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'The air is great!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 65.84,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.35,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 57.44,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.58,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 35.1,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 19.41,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T08:00:00.000Z',
#    'tillDateTime': '2024-06-20T09:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.72},
#     {'name': 'PM10', 'value': 17.17},
#     {'name': 'NO2', 'value': 4.11},
#     {'name': 'O3', 'value': 70.71},
#     {'name': 'SO2', 'value': 5.66},
#     {'name': 'CO', 'value': 302.43}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 17.18,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Zero dust - zero worries!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 70.71,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.14,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 58.1,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.56,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 38.16,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 16.44,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T09:00:00.000Z',
#    'tillDateTime': '2024-06-20T10:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.45},
#     {'name': 'PM10', 'value': 15.48},
#     {'name': 'NO2', 'value': 4.03},
#     {'name': 'O3', 'value': 76.84},
#     {'name': 'SO2', 'value': 5.51},
#     {'name': 'CO', 'value': 298.63}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 15.49,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Breathe deep! The air is clean!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 76.84,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 13.77,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 56.31,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.47,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 34.4,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 16.12,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T10:00:00.000Z',
#    'tillDateTime': '2024-06-20T11:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.03},
#     {'name': 'PM10', 'value': 14.89},
#     {'name': 'NO2', 'value': 3.95},
#     {'name': 'O3', 'value': 80.07},
#     {'name': 'SO2', 'value': 5.89},
#     {'name': 'CO', 'value': 289.84}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 14.9,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Breathe deep! The air is clean!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 80.07,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.74,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 53.51,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.25,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 33.09,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 15.8,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T11:00:00.000Z',
#    'tillDateTime': '2024-06-20T12:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 7.39},
#     {'name': 'PM10', 'value': 13.84},
#     {'name': 'NO2', 'value': 4.31},
#     {'name': 'O3', 'value': 82.85},
#     {'name': 'SO2', 'value': 5.8},
#     {'name': 'CO', 'value': 285.62}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 13.84,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Enjoy life!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 82.85,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.51,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 49.29,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.14,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 30.75,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 17.24,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T12:00:00.000Z',
#    'tillDateTime': '2024-06-20T13:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 7.58},
#     {'name': 'PM10', 'value': 15.22},
#     {'name': 'NO2', 'value': 4.31},
#     {'name': 'O3', 'value': 82.99},
#     {'name': 'SO2', 'value': 5.87},
#     {'name': 'CO', 'value': 294.83}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 15.22,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Breathe to fill your lungs!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'O3',
#      'limit': 100.0,
#      'percent': 82.99,
#      'averaging': '8h'},
#     {'name': 'WHO',
#      'pollutant': 'SO2',
#      'limit': 40.0,
#      'percent': 14.67,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 50.53,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'CO',
#      'limit': 4000.0,
#      'percent': 7.37,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 33.82,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'NO2',
#      'limit': 25.0,
#      'percent': 17.23,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T13:00:00.000Z',
#    'tillDateTime': '2024-06-20T14:00:00.000Z',
#    'values': [],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': None,
#      'level': 'UNKNOWN',
#      'description': 'Unfortunately data from this station is not available for this hour.',
#      'advice': None,
#      'color': '#999999'}],
#    'standards': []}],
#  'forecast': [{'fromDateTime': '2024-06-20T14:00:00.000Z',
#    'tillDateTime': '2024-06-20T15:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 7.78},
#     {'name': 'PM10', 'value': 13.0}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 13.01,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Dear me, how wonderful!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 51.89,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 28.89,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T15:00:00.000Z',
#    'tillDateTime': '2024-06-20T16:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 6.8},
#     {'name': 'PM10', 'value': 10.75}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 11.33,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Green, green, green!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 45.3,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 23.89,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T16:00:00.000Z',
#    'tillDateTime': '2024-06-20T17:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 7.19},
#     {'name': 'PM10', 'value': 11.01}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 12.0,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Breathe deep! The air is clean!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 47.96,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 24.46,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T17:00:00.000Z',
#    'tillDateTime': '2024-06-20T18:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.48},
#     {'name': 'PM10', 'value': 12.66}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 14.13,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'The air is grand today. ;)',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 56.51,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 28.13,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T18:00:00.000Z',
#    'tillDateTime': '2024-06-20T19:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 10.51},
#     {'name': 'PM10', 'value': 15.54}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 17.52,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Green equals clean!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 70.08,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 34.53,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T19:00:00.000Z',
#    'tillDateTime': '2024-06-20T20:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 11.79},
#     {'name': 'PM10', 'value': 18.98}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 19.66,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': "It couldn't be better ;)",
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 78.62,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 42.19,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T20:00:00.000Z',
#    'tillDateTime': '2024-06-20T21:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 12.86},
#     {'name': 'PM10', 'value': 20.62}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 21.44,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': "It couldn't be better ;)",
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 85.75,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 45.83,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T21:00:00.000Z',
#    'tillDateTime': '2024-06-20T22:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 12.84},
#     {'name': 'PM10', 'value': 20.74}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 21.41,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'The air is grand today. ;)',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 85.61,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 46.08,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T22:00:00.000Z',
#    'tillDateTime': '2024-06-20T23:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 12.39},
#     {'name': 'PM10', 'value': 19.29}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 20.66,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Perfect air for exercising! Go for it!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 82.6,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 42.86,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-20T23:00:00.000Z',
#    'tillDateTime': '2024-06-21T00:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 12.52},
#     {'name': 'PM10', 'value': 17.77}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 20.88,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': "It couldn't be better ;)",
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 83.5,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 39.49,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T00:00:00.000Z',
#    'tillDateTime': '2024-06-21T01:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 12.79},
#     {'name': 'PM10', 'value': 17.46}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 21.33,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'The air is grand today. ;)',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 85.3,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 38.79,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T01:00:00.000Z',
#    'tillDateTime': '2024-06-21T02:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 13.28},
#     {'name': 'PM10', 'value': 18.53}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 22.14,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Dear me, how wonderful!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 88.54,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 41.19,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T02:00:00.000Z',
#    'tillDateTime': '2024-06-21T03:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 13.77},
#     {'name': 'PM10', 'value': 19.57}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 22.96,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Breathe to fill your lungs!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 91.81,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 43.49,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T03:00:00.000Z',
#    'tillDateTime': '2024-06-21T04:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 14.07},
#     {'name': 'PM10', 'value': 21.34}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 23.46,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Zero dust - zero worries!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 93.81,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 47.42,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T04:00:00.000Z',
#    'tillDateTime': '2024-06-21T05:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 14.16},
#     {'name': 'PM10', 'value': 21.5}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 23.6,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': "It couldn't be better ;)",
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 94.37,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 47.78,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T05:00:00.000Z',
#    'tillDateTime': '2024-06-21T06:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 13.34},
#     {'name': 'PM10', 'value': 20.87}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 22.24,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': "It couldn't be better ;)",
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 88.93,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 46.39,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T06:00:00.000Z',
#    'tillDateTime': '2024-06-21T07:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 11.99},
#     {'name': 'PM10', 'value': 19.07}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 20.0,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': "It couldn't be better ;)",
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 79.96,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 42.38,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T07:00:00.000Z',
#    'tillDateTime': '2024-06-21T08:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 10.22},
#     {'name': 'PM10', 'value': 16.96}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 17.04,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Enjoy life!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 68.12,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 37.69,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T08:00:00.000Z',
#    'tillDateTime': '2024-06-21T09:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 8.84},
#     {'name': 'PM10', 'value': 14.34}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 14.74,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Catch your breath!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 58.95,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 31.87,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T09:00:00.000Z',
#    'tillDateTime': '2024-06-21T10:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 7.66},
#     {'name': 'PM10', 'value': 12.53}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 12.77,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Green, green, green!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 51.08,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 27.83,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T10:00:00.000Z',
#    'tillDateTime': '2024-06-21T11:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 7.01},
#     {'name': 'PM10', 'value': 11.57}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 11.7,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Perfect air for exercising! Go for it!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 46.76,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 25.71,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T11:00:00.000Z',
#    'tillDateTime': '2024-06-21T12:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 6.9},
#     {'name': 'PM10', 'value': 11.66}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 11.66,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': "It couldn't be better ;)",
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 46.02,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 25.9,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T12:00:00.000Z',
#    'tillDateTime': '2024-06-21T13:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 6.56},
#     {'name': 'PM10', 'value': 11.7}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 11.7,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': "It couldn't be better ;)",
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 43.76,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 25.99,
#      'averaging': '24h'}]},
#   {'fromDateTime': '2024-06-21T13:00:00.000Z',
#    'tillDateTime': '2024-06-21T14:00:00.000Z',
#    'values': [{'name': 'PM25', 'value': 6.46},
#     {'name': 'PM10', 'value': 11.48}],
#    'indexes': [{'name': 'AIRLY_CAQI',
#      'value': 11.48,
#      'level': 'VERY_LOW',
#      'description': 'Great air here today!',
#      'advice': 'Zero dust - zero worries!',
#      'color': '#6BC926'}],
#    'standards': [{'name': 'WHO',
#      'pollutant': 'PM25',
#      'limit': 15.0,
#      'percent': 43.04,
#      'averaging': '24h'},
#     {'name': 'WHO',
#      'pollutant': 'PM10',
#      'limit': 45.0,
#      'percent': 25.51,
#      'averaging': '24h'}]}]}

# %%
headers = {
        "Accept": "application/json",
        "apikey": 'Y7ib9CyZfvqgcPXxEnSUtRkps8TmSIOb'
    }

# %%
url_location  = f'https://airapi.airly.eu/v2/installations/location?locationId={37}'
response_location = urllib.request.Request(url_location, headers=headers)

# %%
with urllib.request.urlopen(response_location) as response:
    data_location = json.load(response)

# %%
data_location
# Out:
# {'id': 37,
#  'location': {'latitude': 54.380279, 'longitude': 18.620274},
#  'locationId': 37,
#  'address': {'country': 'Polska',
#   'city': 'Gdańsk',
#   'street': 'Aleja Generała Józefa Hallera',
#   'number': None,
#   'displayAddress1': 'Gdańsk',
#   'displayAddress2': 'Aleja Generała Józefa Hallera'},
#  'elevation': 6.29,
#  'airly': False,
#  'sponsor': {'id': 11,
#   'name': 'Główny Inspektorat Ochrony Środowiska',
#   'description': 'Source',
#   'logo': 'https://cdn.airly.eu/logo/GIOs.jpg',
#   'link': 'https://powietrze.gios.gov.pl/pjp/current',
#   'displayName': 'Główny Inspektorat Ochrony Środowiska'}}
